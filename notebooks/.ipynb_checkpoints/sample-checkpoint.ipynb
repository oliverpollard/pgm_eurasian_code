# %%
from SALib.sample import latin
import numpy as np
import pandas as pd
import json

# %%
def ranges_to_problem(ranges):
    problem = {
        'num_vars': len(ranges),
        'names': list(ranges.keys()),
        'bounds': list(ranges.values())
    }
    return problem

param_ranges = {
    "g_pgm_ice_streams_ice_stream": [5000,20000],
    "g_sediment_marine_sediment": [10000,30000],
    "g_sediment_onshore_sediment": [30000,100000],
    "g_sediment_bedrock": [100000,150000],
    "p_ice_stream_interior_dist": [0,1000],
    "p_cold_ice_shear_stress": [120000,200000],
    "p_cold_ice_interior_dist": [300, 1000],
    "p_hybrid_ice_stream_shear_stress": [5000,100000],
    "p_hybrid_ice_stream_dist": [0,600],
    "margin_perc": [0,1],
    "topo_equilib": [0.478,1]
}
problem = ranges_to_problem(param_ranges)

# %%
sample = latin.sample(problem, 1000)

# %%
sample_df = pd.DataFrame(sample, columns=problem['names'])
sample_df.to_csv("sample.csv")

# %%
# Out:
#      g_pgm_ice_streams_ice_stream  g_sediment_marine_sediment  \
# 0                    19332.561030                11329.109295
# 1                    18185.245872                21856.467669
# 2                    14272.563532                25285.328909
# 3                     8356.105428                29755.501530
# 4                    17705.874796                18929.806937
# ..                            ...                         ...
# 995                  12265.329323                28967.721390
# 996                   7458.979671                14987.994271
# 997                   6284.193574                17703.998664
# 998                   6421.862185                13894.264602
# 999                   6354.177177                17619.413277
#
#      g_sediment_onshore_sediment  g_sediment_bedrock  \
# 0                   78845.044746       102319.704069
# 1                   52291.790432       109365.223276
# 2                   64205.634725       125675.541592
# 3                   78539.536309       122561.732694
# 4                   45261.874446       118753.437479
# ..                           ...                 ...
# 995                 34152.477347       146330.461805
# 996                 94027.027041       135897.997758
# 997                 84038.718127       115055.293689
# 998                 94148.393693       111391.111197
# 999                 75293.053929       145369.663715
#
#      p_ice_stream_interior_dist  p_cold_ice_shear_stress  \
# 0                    576.161379            199508.173506
# 1                    326.068909            145855.401278
# 2                     19.900869            122447.949989
# 3                    338.971774            127644.791845
# 4                    742.491753            128550.904318
# ..                          ...                      ...
# 995                   53.158018            122997.348695
# 996                   92.789064            196871.899460
# 997                  572.480053            152101.880263
# 998                  688.303548            188961.774557
# 999                  111.993766            132368.302813
#
#      p_cold_ice_interior_dist  p_hybrid_ice_stream_shear_stress  \
# 0                  637.580836                      86373.219391
# 1                  608.999623                      69475.176246
# 2                  483.997175                      27612.262770
# 3                  512.675422                      93599.833170
# 4                  700.459139                      95971.284280
# ..                        ...                               ...
# 995                915.695996                      58877.273168
# 996                909.439851                      66681.838404
# 997                724.847117                      38062.229443
# 998                575.762869                      37049.757147
# 999                359.911514                      99608.748025
#
#      p_hybrid_ice_stream_dist  margin_perc  topo_equilib
# 0                  280.384414     0.005552      0.786091
# 1                   23.421606     0.933965      0.777497
# 2                   90.990068     0.914515      0.525932
# 3                  165.573862     0.064062      0.874530
# 4                  528.495200     0.466690      0.755788
# ..                        ...          ...           ...
# 995                507.694161     0.414693      0.887681
# 996                535.587415     0.240219      0.520561
# 997                 49.596003     0.155302      0.898444
# 998                254.784128     0.571067      0.921878
# 999                506.993233     0.303020      0.717957
#
# [1000 rows x 11 columns]
